# %%
import control
import matplotlib.pyplot as plt

# %%
# Define transfer function of the system
s = control.tf('s')

# %% [markdown]
# ## Process

# %%
G1  = ((s-4)*(s-7))/((s+5)*(s+7))

# %%
G2  = 12/(50*s+1)

# %%
sys = control.series(G1,G2)
sys
# Out:
# TransferFunction(array([  12, -132,  336]), array([  50,  601, 1762,   35]))

# %%
# Simulate step response
t, y = control.step_response(sys)

# %%
# Plot step response
plt.plot(t, y)
plt.xlabel('Time (s)')
plt.ylabel('Output')
plt.title('System Step Response')
plt.grid()
plt.show()
